# %%
from sklearn.model_selection import ShuffleSplit
from skimage.feature import hog
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
import itertools
import matplotlib.image as mpimg
import pandas as pd
import numpy as np
import copy
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import glob
import cv2
import pickle

import data
import model
import postprocess
import constants as c
# %matplotlib inline

# %%
# Read in all the car and non-car classes
vehicle_data = data.retrieve_data("vehicles")
non_vehicle_data = data.retrieve_data("non-vehicles")

df = pd.concat([vehicle_data, non_vehicle_data])
df
# Out:
#           category      subcategory  \
# 0         vehicles  KITTI_extracted
# 1         vehicles  KITTI_extracted
# 2         vehicles  KITTI_extracted
# 3         vehicles  KITTI_extracted
# 4         vehicles  KITTI_extracted
# 5         vehicles  KITTI_extracted
# 6         vehicles  KITTI_extracted
# 7         vehicles  KITTI_extracted
# 8         vehicles  KITTI_extracted
# 9         vehicles  KITTI_extracted
# 10        vehicles  KITTI_extracted
# 11        vehicles  KITTI_extracted
# 12        vehicles  KITTI_extracted
# 13        vehicles  KITTI_extracted
# 14        vehicles  KITTI_extracted
# 15        vehicles  KITTI_extracted
# 16        vehicles  KITTI_extracted
# 17        vehicles  KITTI_extracted
# 18        vehicles  KITTI_extracted
# 19        vehicles  KITTI_extracted
# 20        vehicles  KITTI_extracted
# 21        vehicles  KITTI_extracted
# 22        vehicles  KITTI_extracted
# 23        vehicles  KITTI_extracted
# 24        vehicles  KITTI_extracted
# ...

# %%
# Shuffle and do train-test split

# TODO Later: Split the data manually so that time series issues do not impact the validation results
cv = ShuffleSplit(n_splits=1, test_size=0.2, random_state=0).split(df)

# Since n_splits is 1, generator should only produce one object
train_idx, test_idx = next(cv)

df['dataset'] = 'test'
df['dataset'].iloc[train_idx.tolist()] = 'train'


print("Length of data: ", len(df))
# Out:
# Length of data:  9866

# %%
# For optimizing the subset, we need to be able to rely on validation figures
# Hence, we only use KITTI_extracted data given that the other data sets have timelapse info
# (i.e. high correlation between some images) + non-vehicles images
subset_df = pd.concat([df[df['subcategory'] == 'KITTI_extracted'], df[df['category'] == 'non-vehicles']])

# %%
import importlib
importlib.reload(model)

# Plot bounding boxes of the sliding window search:

# First, read in some test images
test_imgs = np.array([plt.imread(path) for path in glob.glob("test_images/*.jpg")])

# Read in a model so we can use the sliding window function:
svc_model = pickle.load(open('models/svc_model%s.p' % (c.SAVE_LOAD_APPENDIX), 'rb'))
le = pickle.load(open('models/le%s.p' % (c.SAVE_LOAD_APPENDIX), 'rb'))
X_scaler = pickle.load(open('models/X_scaler%s.p' % (c.SAVE_LOAD_APPENDIX), 'rb'))
    
# Run the sliding window search:
heatmaps1, detections1, sliding_window1 = model.get_sliding_window_preds(test_imgs, svc_model, X_scaler, le, c.ORIENT, c.PIX_PER_CELL, c.CELL_PER_BLOCK, 
                               y_start=400, y_stop=656, cell_stride=2,
                               scale=1, colorspace=c.COLORSPACE, spatial_size=c.COLOR_BIN_SHAPE, hist_bins=c.NUM_HIST_BINS, show_window=True)

heatmaps2, detections2, sliding_window2 = model.get_sliding_window_preds(test_imgs, svc_model, X_scaler, le, c.ORIENT, c.PIX_PER_CELL, c.CELL_PER_BLOCK, 
                               y_start=400, y_stop=656, cell_stride=2,
                               scale=1.5, colorspace=c.COLORSPACE, spatial_size=c.COLOR_BIN_SHAPE, hist_bins=c.NUM_HIST_BINS, show_window=True)

heatmaps3, detections3, sliding_window3 = model.get_sliding_window_preds(test_imgs, svc_model, X_scaler, le, c.ORIENT, c.PIX_PER_CELL, c.CELL_PER_BLOCK, 
                               y_start=400, y_stop=500, cell_stride=2,
                               scale=0.75, colorspace=c.COLORSPACE, spatial_size=c.COLOR_BIN_SHAPE, hist_bins=c.NUM_HIST_BINS, show_window=True)

# %%
# plt.figure(figsize=(20,20))
# plt.imshow(sliding_window / 255.)

for idx in range(len(test_imgs)):
    boxed1 = cv2.addWeighted(test_imgs[idx], 0.5, sliding_window1, 0.5, 0)
    boxed2 = cv2.addWeighted(test_imgs[idx], 0.5, sliding_window2, 0.5, 0)
    boxed3 = cv2.addWeighted(test_imgs[idx], 0.5, sliding_window3, 0.5, 0)
    
    # Draw the original image, heatmap and resultant bboxes
    fig = plt.figure(figsize=(15,10))        
    plt.subplot(141).imshow(test_imgs[idx])
    plt.subplot(142).imshow(boxed1)
    plt.subplot(143).imshow(boxed2)
    plt.subplot(144).imshow(boxed3)

    plt.show()

# %%
for idx in range(len(test_imgs)):
    boxed1 = cv2.addWeighted(test_imgs[idx], 1, detections1[idx], 0.5, 0)
    boxed2 = cv2.addWeighted(test_imgs[idx], 1, detections2[idx], 0.5, 0)
    boxed3 = cv2.addWeighted(test_imgs[idx], 1, detections3[idx], 0.5, 0)
    boxedAll = cv2.addWeighted(test_imgs[idx], 1, detections1[idx], 0.5, 0)
    boxedAll = cv2.addWeighted(boxedAll, 1, detections2[idx], 0.5, 0)
    boxedAll = cv2.addWeighted(boxedAll, 1, detections3[idx], 0.5, 0)
    
    # Draw the original image, heatmap and resultant bboxes
    fig = plt.figure(figsize=(15,10))        
    plt.subplot(151).imshow(test_imgs[idx])
    plt.subplot(152).imshow(boxed1)
    plt.subplot(153).imshow(boxed2)
    plt.subplot(154).imshow(boxed3)
    plt.subplot(155).imshow(boxedAll)

    plt.show()

# %%
for idx in range(len(test_imgs)):
    boxedAll = cv2.addWeighted(heatmaps1[idx], 0.5, heatmaps2[idx], 1, 0)
    boxedAll = cv2.addWeighted(boxedAll, 1, heatmaps3[idx], 1, 0)
    
    # Draw the original image, heatmap and resultant bboxes
    fig = plt.figure(figsize=(15,10))        
    plt.subplot(151).imshow(test_imgs[idx])
    plt.subplot(152).imshow(heatmaps1[idx])
    plt.subplot(153).imshow(heatmaps2[idx])
    plt.subplot(154).imshow(heatmaps3[idx])
    plt.subplot(155).imshow(boxedAll)

    plt.show()
